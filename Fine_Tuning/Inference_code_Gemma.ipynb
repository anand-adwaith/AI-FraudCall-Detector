# %%
import pandas as pd
import torch
import time
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load test data
df = pd.read_csv("Test_Dataset.csv", encoding='cp1252')
df = df[['text', 'label']].dropna()
df['label'] = df['label'].str.lower().str.strip()
label_map = {'fraud': 1, 'normal': 0}
df['label_id'] = df['label'].map(label_map)

# Load tokenizer and base model (Gemma 2B)
base_model_path = r"C:\Users\HAN4COB\.conda\envs\test\AI_Enabled_Scam_Call_Detection\gemma-2b"
lora_adapter_path = r"C:\Users\HAN4COB\.conda\envs\test\AI_Enabled_Scam_Call_Detection\gemma2b-finetuned\kaggle\working\gemma2b-finetuned\checkpoint-2250"

tokenizer = AutoTokenizer.from_pretrained(base_model_path, local_files_only=True)
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    torch_dtype=torch.float32,
    device_map={"": "cpu"},
    local_files_only=True
)
model = PeftModel.from_pretrained(base_model, lora_adapter_path, device_map={"": "cpu"}, local_files_only=True)
model.eval()

# Classify function
def classify(text):
    prompt = f"Classify this call:\n{text}\nLabel:"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, padding=True).to("cpu")

    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_new_tokens=5,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id
        )
    decoded = tokenizer.decode(output[0], skip_special_tokens=True)
    label = decoded.split("Label:")[-1].strip().lower()

    # Mapping label text to binary
    fraud_keywords = ["fraud", "urgent", "loan", "kyc", "promotion", "limited", "alert", "job", "click", "investment"]
    normal_keywords = ["normal", "chat", "call", "personal", "fun", "home", "invitation", "friend", "plan"]

    if any(k in label for k in fraud_keywords):
        return 1, label
    elif any(k in label for k in normal_keywords):
        return 0, label
    else:
        return None, label

# Inference
preds, labels, texts, raw_preds = [], [], [], []
start_time = time.time()

for _, row in df.iterrows():
    pred, raw = classify(row['text'])
    raw_preds.append(raw)
    if pred is not None:
        preds.append(pred)
        labels.append(row['label_id'])
        texts.append(row['text'])

total_time = time.time() - start_time
avg_time = total_time / len(df)

# Metrics
if preds:
    acc = accuracy_score(labels, preds)
    prec = precision_score(labels, preds, zero_division=0)
    rec = recall_score(labels, preds, zero_division=0)
    f1 = f1_score(labels, preds, zero_division=0)
else:
    acc = prec = rec = f1 = 0.0

# Print detailed results
for i, (t, p, r, raw) in enumerate(zip(texts, labels, preds, raw_preds[:len(preds)])):
    result = "✅" if p == r else "❌"
    print(f"[{i+1:03}] {result} True: {'fraud' if r else 'normal'} | Pred: {'fraud' if p else 'normal'} | Raw: {raw}\n     Text: {t[:100]}...\n")

# Final metrics
print("\n✅ Overall Evaluation Metrics (on", len(preds), "samples):")
print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1 Score : {f1:.4f}")
print(f"\n⏱️ Total Inference Time   : {total_time:.2f} sec")
print(f"⏱️ Avg Time per Sample     : {avg_time:.2f} sec")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [001] ✅ True: fraud | Pred: fraud | Raw: urgent
# share: share
#      Text: Nani, it’s your favorite grandson. I’m stranded in Goa with no money. Send Rs. 3,000 at http://trave...
#
# [002] ✅ True: fraud | Pred: fraud | Raw: urgent
# share: share
#      Text: Uncle, it’s Aman. I’m in deep trouble in Ahmedabad. Need Rs. 9,000 to escape danger. Click http://sa...
#
# [003] ✅ True: fraud | Pred: fraud | Raw: urgent
# call type:
#      Text: Mummy, I’ve been in a bike crash in Bangalore. I’m bleeding. Need Rs. 8,000 now. Click http://urgent...
#
# [004] ✅ True: fraud | Pred: fraud | Raw: urgent
# call type:
#      Text: Dad, I’ve been in a bike accident in Gurgaon. Need Rs. 6,500 for hospital bills. Click http://gurgao...
#
# [005] ✅ True: fraud | Pred: fraud | Raw: urgent! your parcel is
#      Text: Hello madam, this is from the courier company. Your package is stuck due to unpaid customs duty. Ple...
#
# [006] ✅ True: fraud | Pred: fraud | Raw: limited time offer
# call
#      Text: Congratulations! You've been chosen as our lucky winner for a new refrigerator. Kindly confirm your ...
#
# [007] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this message
#      Text: ATTENTION! Your Myntra order missed delivery. Reschedule fast at http://myntra-redeliver.co.in befor...
#
# [008] ✅ True: fraud | Pred: fraud | Raw: urgent
# category: urgent
#      Text: Urgent! Your Amazon parcel is delayed due to address error. Update at http://amazon-fixdelivery.co.i...
#
# [009] ✅ True: fraud | Pred: fraud | Raw: urgent
# share otp to
#      Text: Dear customer, we noticed some unusual activity on your bank account. To secure your funds, kindly s...
#
# [010] ✅ True: fraud | Pred: fraud | Raw: urgent
# share:
#      Text: Dear customer, this is an urgent notice from your electric board. Your bill payment is overdue, and ...
#
# [011] ✅ True: fraud | Pred: fraud | Raw: loan
# category: personal
#      Text: Congratulations! You’ve won a Rs. 5 Lakh loan from ICICI. Claim now at http://icici-quickloan.co or ...
#
# [012] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this message
#      Text: Don’t ignore! Your HDFC credit card limit is reduced due to non-payment. Pay now: http://hdfc-cardpa...
#
# [013] ✅ True: fraud | Pred: fraud | Raw: urgent
# share your pan
#      Text: Dear customer, your PAN card is scheduled for suspension due to incomplete KYC. Kindly share your da...
#
# [014] ✅ True: fraud | Pred: fraud | Raw: urgent
# share your otp
#      Text: Hello, this is customer care from Reserve Bank of India. There's a mismatch in your KYC documents. K...
#
# [015] ✅ True: fraud | Pred: fraud | Raw: urgent
# category: important
#      Text: Namaste sir, this is Suresh calling from the Income Tax department. There is an urgent notice agains...
#
# [016] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Fraud alert! Protect your Aadhaar from misuse. Click http://id-guardindia.net now or face severe con...
#
# [017] ✅ True: fraud | Pred: fraud | Raw: urgent
# share:
#      Text: Hello, this is Ramesh from the Income Tax Department. There is a mismatch in your PAN details. To av...
#
# [018] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this message
#      Text: GST Notice: Unpaid dues detected. Pay now to avoid penalty at http://gstpay-india.org or face arrest...
#
# [019] ✅ True: fraud | Pred: fraud | Raw: urgent
# category: financial
#      Text: Hello madam, caller from Income Tax department. There is a case on your PAN card due to suspicious t...
#
# [020] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Dear Sir/Madam, your Ration Card benefits are expiring. Renew at http://ration-indiarenew.co or lose...
#
# [021] ✅ True: fraud | Pred: fraud | Raw: limited time offer
# share
#      Text: Congratulations! You've been selected for an exclusive investment plan with double returns in 6 mont...
#
# [022] ✅ True: fraud | Pred: fraud | Raw: promotion
# category: investment
#      Text: Good evening madam, I am calling from LIC India. There is a new investment policy for premium custom...
#
# [023] ✅ True: fraud | Pred: fraud | Raw: investment
# share:
#      Text: Hello madam, this is from Future Returns Investments. Our new scheme doubles your principal in just ...
#
# [024] ✅ True: fraud | Pred: fraud | Raw: investment
# share this link
#      Text: Final warning! Miss this Chennai crypto deal & lose big. Invest today: http://chennaicryptohub.com...
#
# [025] ✅ True: fraud | Pred: fraud | Raw: investment
# share this link
#      Text: Last chance! Join our secret Nifty trading group & earn lakhs overnight. Hurry: http://niftyrich-ind...
#
# [026] ✅ True: fraud | Pred: fraud | Raw: urgent
# share your upi
#      Text: Namaste, this is Ramesh from HR department. For final round of your job interview at Infosys, we nee...
#
# [027] ✅ True: fraud | Pred: fraud | Raw: investment
# share: share
#      Text: High-Paying Job! ?25,000/week from Kolkata. No interview. Secure spot: http://koljobsfast.co.in...
#
# [028] ✅ True: fraud | Pred: fraud | Raw: paid
# share:
#      Text: IMMEDIATE HIRING! Earn ?800/day from home. No skills required. Hurry: http://easyjobindia.live...
#
# [029] ❌ True: normal | Pred: fraud | Raw: promotion
# share this link
#      Text: Get instant approval for your cash loan! Just share your PAN and Aadhar to fast-track the process. C...
#
# [030] ❌ True: normal | Pred: fraud | Raw: personal
# category: personal
#      Text: Dear customer, you have been chosen for an exclusive SBI home loan offer at 2% interest! Please conf...
#
# [031] ❌ True: normal | Pred: fraud | Raw: upgrade
# call:
#      Text: Hello, this is Bajaj Finance. You are pre-approved for a personal loan up to Rs. 5 lakh with 0% inte...
#
# [032] ✅ True: fraud | Pred: fraud | Raw: pre-approved
# call
#      Text: Instant loan of Rs. 7 lakhs waiting for you! Apply in 2 mins at http://easyfunds.bharatloan.in or lo...
#
# [033] ✅ True: fraud | Pred: fraud | Raw: investment
# share this link
#      Text: Struggling with bills? Rs. 3 lakh loan ready now. Click http://quickhelp.bharatrupee.co or lose this...
#
# [034] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Struggling with EMIs? Rs. 5.5 lakh loan to rescue you. Act now: http://emihelp.bharatfund.in or call...
#
# [035] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Family in need? Rs. 4 lakh loan approved instantly. Secure at: http://safefund.loanhelp.in or lose t...
#
# [036] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Congratulations! You've won a brand new Honda Activa in our lucky draw. To verify and process delive...
#
# [037] ✅ True: fraud | Pred: fraud | Raw: promotional
# share your aad
#      Text: Congratulations! Your mobile number has been randomly selected for a reward of Rs. 50,000. Kindly sh...
#
# [038] ✅ True: fraud | Pred: fraud | Raw: limited time offer
# share
#      Text: Congrats! Your number is selected for a lucky draw prize. Please verify your account details to clai...
#
# [039] ✅ True: fraud | Pred: fraud | Raw: limited-time offer
#      Text: Lucky Winner! Rs. 3 lakh awaits you in KBC Lottery! Call 9876543210 or click http://kbcwin.officialp...
#
# [040] ✅ True: fraud | Pred: fraud | Raw: limited time offer
# label
#      Text: Dear customer, your Paytm KYC is expiring soon. Please click the link sent to update your details or...
#
# [041] ✅ True: fraud | Pred: fraud | Raw: urgent
# call type:
#      Text: Your SBI NetBanking has been suspended due to suspicious activity. Click the secure link to re-activ...
#
# [042] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this message
#      Text: Hello madam, this is from IRCTC customer care. There was some suspicious activity on your account. K...
#
# [043] ✅ True: fraud | Pred: fraud | Raw: urgent
# call type:
#      Text: Immediate action required! Your Kotak account is compromised. Secure it: http://kotak-safeaccess.in...
#
# [044] ✅ True: fraud | Pred: fraud | Raw: urgent
# share your otp
#      Text: Good afternoon, your electricity bill is pending due to a system error. To avoid immediate disconnec...
#
# [045] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this message
#      Text: Warning! Your electricity bill is unpaid. Avoid power cut, pay immediately at http://powerbill-india...
#
# [046] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Hurry! Your Reliance broadband will be cut off. Secure it at http://reliance-netpay.co.in before it'...
#
# [047] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Danger! Your Tata Sky subscription expires today. Renew urgently at http://tatasky-renewfast.com or ...
#
# [048] ✅ True: fraud | Pred: fraud | Raw: urgent
# share: share
#      Text: Your Netflix subscription renewal failed. Please verify your card details at the link sent on SMS to...
#
# [049] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this message
#      Text: Hey, your JioCinema subscription is expiring soon. Renew at Rs.99 or miss out: http://jiocinema-rech...
#
# [050] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Your Netflix account will auto-renew at Rs.799. Cancel now to save money: http://netflix-cancelplan....
#
# [051] ✅ True: fraud | Pred: fraud | Raw: urgent
# call type:
#      Text: Hey, your JioCinema subscription is expiring soon. Renew at Rs.99 or miss out: http://jiocinema-rech...
#
# [052] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this link
#      Text: Warning! Virus detected on your device. Secure it urgently by calling 1-800-333-9876 before data los...
#
# [053] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this message
#      Text: Critical Alert! Your phone is infected with malware. Call our tech support at 1800-444-5678 now to s...
#
# [054] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this post
#      Text: Help! Your personal data is being stolen. Call our tech team at 1-800-999-4455 to lock it down. Act ...
#
# [055] ✅ True: fraud | Pred: fraud | Raw: urgent
# share this post
#      Text: PANIC! Your device is under attack. Secure it at http://techguard-india.live or face complete data w...
#
# [056] ❌ True: fraud | Pred: normal | Raw: urgent
# share this link
#      Text: Just checked, your shoes arrived at the gate. Want me to keep them inside or leave at your door?...
#
# [057] ❌ True: fraud | Pred: normal | Raw: urgent
# reply: keep
#      Text: Your order has been dispatched. Expect it by tomorrow afternoon in Bangalore....
#
# [058] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Good news! Your parcel from Amazon is out for delivery. Should reach by 3 PM today....
#
# [059] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Your Myntra order has been dispatched. Delivery expected within 2 days in Chennai....
#
# [060] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Did you submit the application for the campus fest, or should I handle it today?...
#
# [061] ❌ True: fraud | Pred: normal | Raw: urgent
#      Text: Aunty, is the tuition class at 5 or they changed it again?...
#
# [062] ❌ True: fraud | Pred: normal | Raw: pass
# reason: passed
#      Text: Hey, did you finish the Chemistry assignment? Need help with the last question....
#
# [063] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Heard you got the tickets for tonight? Let me know what time to meet at the gate....
#
# [064] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Hey, did you manage to get tickets for the Saturday night movie show, or should I try booking from m...
#
# [065] ✅ True: normal | Pred: normal | Raw: urgent
# share this message
#      Text: Yo, IPL highlights last night were crazy! Did you see that last over? Let’s discuss....
#
# [066] ❌ True: fraud | Pred: normal | Raw: urgent
#      Text: Rohit, do you remember where we kept the electricity bill receipt? I need it for tomorrow's paperwor...
#
# [067] ✅ True: normal | Pred: normal | Raw: match-winning
# call
#      Text: Hey, can you send me that recipe video again? Amma wants to try it for dinner tonight....
#
# [068] ❌ True: fraud | Pred: normal | Raw: recommendation
#      Text: Bhai, mom said to bring some dahi on your way back, ok? Don't forget this time!...
#
# [069] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Will you be coming for badminton this evening or still working late?...
#
# [070] ✅ True: normal | Pred: normal | Raw: call type: reminder
#      Text: Let’s watch the India-Pakistan match at my place tonight. Snacks on me!...
#
# [071] ✅ True: normal | Pred: normal | Raw: urgent
# call type:
#      Text: Let’s go cycling near Powai Lake early tomorrow. Fresh air and a quick ride!...
#
# [072] ❌ True: fraud | Pred: normal | Raw: received
# classification: food
#      Text: Outside food allowed at the venue? Or should I bring snacks for everyone?...
#
# [073] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Hey, did you manage to recharge the DTH? The kids are asking for cartoons already....
#
# [074] ❌ True: fraud | Pred: normal | Raw: activity
# â€”
#      Text: Just checked with the tailor, your suit will be ready by Friday evening. Do you want to pick it up o...
#
# [075] ✅ True: normal | Pred: normal | Raw: invitation
# â€”
#      Text: Can you share the menu for North Indian thali at your restaurant?...
#
# [076] ❌ True: fraud | Pred: normal | Raw: invitation
# â€”
#      Text: Are you free for a quick chat this evening or should I call you tomorrow?...
#
# [077] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Can you check if my headphones are at your place? I think I left them last night....
#
# [078] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Macha, did you check if the chaiwala near office started making samosas again?...
#
# [079] ✅ True: normal | Pred: normal | Raw: urgent
# reply: pick
#      Text: You coming to the Ganpati visarjan tomorrow? Let’s go together!...
#
# [080] ❌ True: fraud | Pred: normal | Raw: call type:
#      Text: Are you coming for cricket practice in the evening or should I update coach?...
#
# [081] ✅ True: normal | Pred: normal | Raw: urgent
# call type:
#      Text: Did you see the match last night? Dhoni's six gave me goosebumps, man!...
#
# [082] ✅ True: normal | Pred: normal | Raw: urgent
# call type:
#      Text: Let’s watch the Kabaddi Pro League tonight. You in?...
#
# [083] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Nana, did you check if the train tickets got confirmed for next week?...
#
# [084] ❌ True: fraud | Pred: normal | Raw: invitation
# call type:
#      Text: Reached the hotel safely, the room is nice and wifi's working fine. Let me know if you need anything...
#
# [085] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Just landed in Hyderabad, will reach the hotel in thirty minutes. Want to meet for dinner?...
#
# [086] ❌ True: fraud | Pred: normal | Raw: exciting
# call type:
#      Text: Arriving in Chennai at 9 AM. Can we grab some idli-vada for breakfast?...
#
# [087] ❌ True: fraud | Pred: normal | Raw: match
# classify this call
#      Text: Hey, I'm stuck in the metroâ€”will reach office about 20 minutes late, okay?...
#
# [088] ❌ True: fraud | Pred: normal | Raw: achievement
# date:
#      Text: Did you see the email from HR? They moved the team meeting to Thursday morning, just letting you kno...
#
# [089] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Can you please send me that Excel file again? I think my inbox deleted it by mistake....
#
# [090] ❌ True: fraud | Pred: normal | Raw: urgent
# call type:
#      Text: Project update: Client call at 2 PM. Join the Zoom link, okay?...
#
# [091] ❌ True: fraud | Pred: normal | Raw: urgent
# reply: yes
#      Text: Papa, did you pick up my charger from the living room? I need it for my online class....
#
# [092] ❌ True: fraud | Pred: normal | Raw: urgent
# share this message
#      Text: Macha, metro timings have changed again yaar, you saw the new schedule?...
#
# [093] ❌ True: fraud | Pred: normal | Raw: urgent
#      Text: I reached the shop but they said the item is out of stock, should I check the other branch?...
#
# [094] ❌ True: fraud | Pred: normal | Raw: urgent
# share this post
#      Text: Did you remember to submit the travel allowance form to HR or should I check with them tomorrow?...
#
#
# ✅ Overall Evaluation Metrics (on 94 samples):
# Accuracy : 0.6383
# Precision: 0.6265
# Recall   : 0.9455
# F1 Score : 0.7536
#
# ⏱️ Total Inference Time   : 157.50 sec
# ⏱️ Avg Time per Sample     : 1.58 sec
